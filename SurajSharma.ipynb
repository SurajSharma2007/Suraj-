# %% [markdown]
# <a href="https://colab.research.google.com/github/SurajSharma2007/Suraj-/blob/main/SurajSharma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("python is a computer language")
# Out:
# python is a computer language

# %%
a=10
b=20
c=a+b
print("sum=",c)
# Out:
# sum= 30
